# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO('yolov8n.pt')
results = model('street.jpg')
img_annotated= results[0].plot()
plt.figure(figsize=(10,10))
plt.imshow(img_annotated)
plt.title('Objects Detection')
plt.axis('off')
plt.show()
# Out:
# image 1/1 D:\WEB\Python\python-ai-62\05_yolo_intro\street.jpg: 640x512 6 persons, 1 bicycle, 1 car, 183.6ms
# Speed: 6.0ms preprocess, 183.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
