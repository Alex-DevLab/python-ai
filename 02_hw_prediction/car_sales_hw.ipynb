# %%
import pandas as pd

df = pd.read_csv('../data/car_sales_cleaned1.csv')
df = df.drop_duplicates()
df = df.dropna()
df
# Out:
#        Gender  Annual Income    Company       Model Transmission       Color  \
# 0        Male          13500       Ford  Expedition         Auto       Black
# 1        Male        1480000      Dodge     Durango         Auto       Black
# 2        Male        1035000   Cadillac    Eldorado       Manual         Red
# 3        Male          13500     Toyota      Celica       Manual  Pale White
# 4        Male        1465000      Acura          TL         Auto         Red
# ...       ...            ...        ...         ...          ...         ...
# 23898    Male         530000      Volvo         C70       Manual  Pale White
# 23900  Female         771000       Ford     Contour         Auto         Red
# 23902  Female         900000  Chevrolet       Prizm         Auto       Black
# 23903    Male         705000        BMW        328i       Manual         Red
# 23905    Male        1225000      Lexus       ES300         Auto  Pale White
#
#        Price ($)
# 0          26000
# ...
