# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from fontTools.diff import color

img1 = np.zeros((100, 100, 3), dtype="uint8")
img1[50][50][0] = 255
plt.axis('off')
plt.imshow(img1)
plt.show()

# %%
#diagonal
height = 100
width = 100
img1 = np.zeros((height, width, 3), dtype="uint8")
for i in range(height):
    for j in range(width):
        if i == j:
            img1[i][j][0] = 106  # R - red
            img1[i][j][1] = 31  # G - green
            img1[i][j][2] = 191  # B - blue

plt.axis('off')
plt.imshow(img1)
plt.show()

# %%
#diagonal
height = 100
width = 100
img1 = np.zeros((height, width, 3), dtype="uint8")
cv2.line(img1, (0, 0), (width, height), color=(106, 31, 191))
plt.axis('off')
plt.imshow(img1)
plt.show()

# %%
#diagonal
height = 100
width = 100
img1 = np.zeros((height, width, 3), dtype="uint8")
cv2.line(img1, (0, height), (width, 0), color=(106, 31, 191))
plt.axis('off')
plt.imshow(img1)
plt.show()

# %%
cv2.line(img1, (0, 0), (width, height), color=(106, 31, 191))
cv2.line(img1, (0, height), (width, 0), color=(106, 31, 191))
cv2.line(img1, (0, height // 2), (width, height // 2), color=(106, 31, 191))
cv2.line(img1, (width // 2, 0), (width // 2, height), color=(106, 31, 191))
# plt.axis('off')
plt.imshow(img1)
plt.show()

# %%
cv2.circle(img1, (width // 2, height // 2), width // 3, color=(0, 255, 0), thickness=1)
plt.axis()
plt.imshow(img1)
plt.show()

# %%
img2 = np.random.randint(0, 256, (100, 100, 3), dtype="uint8")
plt.axis("off")
plt.imshow(img2)
plt.show()

# %%
height = 100
width = 100

# 1 -----------
# img3 = np.random.randint(0,256,(height,width), dtype = "uint8")

# 2 -----------
# img3 = np.zeros((height, width), dtype="uint8")
# for i in range(height):
#     for j in range(width):
#         rnd = np.random.randint(0, 2)
#         if rnd == 0:
#             img3[i][j] = 0
#         else:
#             img3[i][j] = 255

# 3 -----------
img3 = np.random.randint(0, 2, (height, width), dtype="uint8") * 255

plt.axis("off")
plt.imshow(img3, cmap="gray")
plt.show()

# %%
values = np.array([0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100])
plt.plot(values, color="red")
plt.title("Simple plot line")
plt.show()

# %%
bg= np.full((100,100), 200, dtype="uint8")
plt.imshow(bg, cmap="gray", vmin=0, vmax=255) # contrast
plt.show()

# %%
import random
img4 = np.full((30,30), 255, dtype="uint8")
for i in range(30):
    for j in range(30):
        img4[i][j]= 0 if random.randint(0,2) == 1 else 150

plt.imshow(img4, cmap="gray", vmin=0, vmax=255)
plt.show()
